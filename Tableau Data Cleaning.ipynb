# %%
import pandas as pd

# %%
df = pd.read_csv('MGOclean.csv')

# %%
df2 = pd.read_csv('cleandes.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                    clean_des_col_2
# 0           0     i live in austin tx based on my address but...
# 1           1     i already have an account  how do i registe...
# 2           2     please let us know where we send the docume...
# 3           3     i have a noc that is not appearing and i wa...
# 4           4     i have fixed the problem swepco said i had ...

# %%
len(df)
# Out:
# 41751

# %%
len(df2)
# Out:
# 93967

# %%
df2.head()
# Out:
#    Unnamed: 0   Issue key  Issue id        Status  \
# 0           0  MWS-123772  184523.0  Acknowledged
# 1           1  MWS-123771  184522.0  Acknowledged
# 2           2  MWS-123770  184521.0  Acknowledged
# 3           3  MWS-123769  184520.0  Acknowledged
# 4           4  MWS-123768  184518.0  Acknowledged
#
#                                  Project description Resolution  \
# 0  receives all form mail from the mygovernmenton...        NaN
# 1  receives all form mail from the mygovernmenton...        NaN
# 2  receives all form mail from the mygovernmenton...        NaN
# 3  receives all form mail from the mygovernmenton...        NaN
# 4  receives all form mail from the mygovernmenton...        NaN
#
#                Created         Updated          Last Viewed Resolved  ...  \
# 0  2022-10-25 19:26:00  10/25/22 19:26  2022-10-25 20:14:00      NaN  ...
# 1  2022-10-25 18:34:00  10/25/22 18:34  2022-10-25 20:14:00      NaN  ...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93967 entries, 0 to 93966
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    93967 non-null  int64
#  1   Issue key                     93945 non-null  object
#  2   Issue id                      93945 non-null  float64
#  3   Status                        93945 non-null  object
#  4   Project description           93945 non-null  object
#  5   Resolution                    93337 non-null  object
#  6   Created                       93945 non-null  object
#  7   Updated                       93945 non-null  object
#  8   Last Viewed                   93945 non-null  object
#  9   Resolved                      93337 non-null  object
#  10  Due date                      0 non-null      float64
#  11  Description                   93802 non-null  object
# ...

# %%
import pandas as pd

# Assume that df1 and df2 are both pandas DataFrames

# Get the column from df1 that you want to search for in df2
column_to_search = df['clean_des_col_2']

# Use the `isin()` method to check if the values in the column from df1 are in the corresponding column in df2
matching_columns = df2['clean_des_col_2'].isin(column_to_search)

# You can use the resulting boolean series to filter the rows of df2
df3= df2[matching_columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41751 entries, 0 to 93965
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    41751 non-null  int64
#  1   Issue key                     41751 non-null  object
#  2   Issue id                      41751 non-null  float64
#  3   Status                        41751 non-null  object
#  4   Project description           41751 non-null  object
#  5   Resolution                    41671 non-null  object
#  6   Created                       41751 non-null  object
#  7   Updated                       41751 non-null  object
#  8   Last Viewed                   41751 non-null  object
#  9   Resolved                      41671 non-null  object
#  10  Due date                      0 non-null      float64
#  11  Description                   41751 non-null  object
# ...

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'Issue key', 'Issue id', 'Status', 'Project description',
#        'Resolution', 'Created', 'Updated', 'Last Viewed', 'Resolved',
#        'Due date', 'Description', 'created_Time', 'created_Date', 'last_Time',
#        'last_Date', 'duration', 'day_of_week', 'lower_description', 'names',
#        'lower_clean_description', 'lower_clean_char_description',
#        'clean_des_col', 'clean_des_col_2'],
#       dtype='object')

# %%
df3['Resolved'].isna().sum()
# Out:
# 80

# %%
df4 = df3.dropna(subset=['Resolved'])

# %%
df4
# Out:
#        Unnamed: 0   Issue key  Issue id  Status  \
# 7               7  MWS-123765  184515.0  Closed
# 14             14  MWS-123758  184508.0  Closed
# 16             16  MWS-123756  184506.0  Closed
# 21             21  MWS-123751  184501.0  Closed
# 22             22  MWS-123750  184500.0  Closed
# ...           ...         ...       ...     ...
# 93961       93961       MWS-6   10619.0  Closed
# 93962       93962       MWS-5   10618.0  Closed
# 93963       93963       MWS-4   10615.0  Closed
# 93964       93964       MWS-3   10610.0  Closed
# 93965       93965       MWS-2   10609.0  Closed
#
#                                      Project description Resolution  \
# 7      receives all form mail from the mygovernmenton...       Done
# 14     receives all form mail from the mygovernmenton...       Done
# 16     receives all form mail from the mygovernmenton...       Done
# 21     receives all form mail from the mygovernmenton...       Done
# ...

# %%
df3.drop(columns = ['Unnamed: 0', 'Issue id','Status', 'Project description',
       'Resolution','Description', 'created_Time', 'created_Date', 'last_Time',
       'last_Date', 'duration', 'day_of_week', 'lower_description', 'names',
       'lower_clean_description', 'lower_clean_char_description',
       'clean_des_col', 'clean_des_col_2'])
# Out:
#         Issue key              Created         Updated          Last Viewed  \
# 0      MWS-123772  2022-10-25 19:26:00  10/25/22 19:26  2022-10-25 20:14:00
# 1      MWS-123771  2022-10-25 18:34:00  10/25/22 18:34  2022-10-25 20:14:00
# 2      MWS-123770  2022-10-25 18:14:00  10/25/22 18:14  2022-10-25 20:14:00
# 3      MWS-123769  2022-10-25 17:42:00  10/25/22 17:42  2022-10-25 20:14:00
# 4      MWS-123768  2022-10-25 16:58:00  10/25/22 16:58  2022-10-25 20:14:00
# ...           ...                  ...             ...                  ...
# 93961       MWS-6  2014-02-14 08:27:00  12/16/20 11:19  2022-10-25 21:14:00
# 93962       MWS-5  2014-02-13 23:29:00  12/16/20 11:19  2022-10-25 21:14:00
# 93963       MWS-4  2014-02-13 12:24:00  12/16/20 11:19  2022-10-25 21:14:00
# 93964       MWS-3  2014-02-12 15:52:00  12/16/20 11:19  2022-10-25 21:14:00
# 93965       MWS-2  2014-02-12 15:34:00  12/16/20 11:19  2022-10-25 21:14:00
#
#                   Resolved  Due date
# ...

# %%
len(df3['Issue key'].value_counts())
# Out:
# 41751

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df4['Resolved']
# Out:
# 7        2022-10-25 16:32:00
# 14       2022-10-25 16:09:00
# 16       2022-10-25 16:03:00
# 21       2022-10-25 15:25:00
# 22       2022-10-25 16:48:00
#                 ...
# 93961    2014-02-20 11:28:00
# 93962    2014-02-20 11:28:00
# 93963    2014-02-20 11:32:00
# 93964    2014-02-20 11:20:00
# 93965    2014-02-18 21:01:00
# Name: Resolved, Length: 41671, dtype: object

# %%
df4['Resolved'].describe()
# Out:
# count                   41671
# unique                  39860
# top       2020-12-16 11:46:00
# freq                       32
# Name: Resolved, dtype: object

# %%
df4['Resolved'] = pd.to_datetime(df4['Resolved'])
df4['Created'] = pd.to_datetime(df4['Created'])
# Out:
# /tmp/ipykernel_478/2434841656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Resolved'] = pd.to_datetime(df4['Resolved'])
# /tmp/ipykernel_478/2434841656.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Created'] = pd.to_datetime(df4['Created'])

# %%
df4['Resolved'].describe()
# Out:
# /tmp/ipykernel_478/3963319366.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df4['Resolved'].describe()
# count                   41671
# unique                  39860
# top       2020-12-16 11:46:00
# freq                       32
# first     2014-02-18 21:01:00
# last      2022-10-25 16:48:00
# Name: Resolved, dtype: object

# %%
df4['Created'].describe()
# Out:
# /tmp/ipykernel_478/3773204838.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df4['Created'].describe()
# count                   41671
# unique                  38624
# top       2019-12-11 12:45:00
# freq                       52
# first     2014-02-12 15:34:00
# last      2022-10-25 16:18:00
# Name: Created, dtype: object

# %%
df4['Due date']
# Out:
# 7       NaN
# 14      NaN
# 16      NaN
# 21      NaN
# 22      NaN
#          ..
# 93961   NaN
# 93962   NaN
# 93963   NaN
# 93964   NaN
# 93965   NaN
# Name: Due date, Length: 41671, dtype: float64

# %%
df4.columns
# Out:
# Index(['Unnamed: 0', 'Issue key', 'Issue id', 'Status', 'Project description',
#        'Resolution', 'Created', 'Updated', 'Last Viewed', 'Resolved',
#        'Due date', 'Description', 'created_Time', 'created_Date', 'last_Time',
#        'last_Date', 'duration', 'day_of_week', 'lower_description', 'names',
#        'lower_clean_description', 'lower_clean_char_description',
#        'clean_des_col', 'clean_des_col_2'],
#       dtype='object')

# %%
 df5 = df4.drop(columns = ['Unnamed: 0', 'Issue key', 'Issue id', 'Status', 'Project description',
       'Resolution','Due date', 'Description', 'created_Time', 'created_Date', 'last_Time',
       'last_Date', 'duration', 'day_of_week', 'lower_description', 'names',
       'lower_clean_description', 'lower_clean_char_description',
       'clean_des_col', 'clean_des_col_2'])

# %%
df5.head()
# Out:
#                Created         Updated          Last Viewed  \
# 7  2022-10-25 16:18:00  10/25/22 16:32  2022-10-25 20:14:00
# 14 2022-10-25 15:54:00  10/25/22 16:09  2022-10-25 20:14:00
# 16 2022-10-25 15:34:00  10/25/22 16:03  2022-10-25 20:14:00
# 21 2022-10-25 15:02:00  10/25/22 16:23  2022-10-25 20:14:00
# 22 2022-10-25 14:58:00  10/25/22 16:48  2022-10-25 20:14:00
#
#               Resolved
# 7  2022-10-25 16:32:00
# 14 2022-10-25 16:09:00
# 16 2022-10-25 16:03:00
# 21 2022-10-25 15:25:00
# 22 2022-10-25 16:48:00

# %%
df5['created_Time'] = df5['Created'].dt.time
df5['created_Date'] = df5['Created'].dt.date
print(df5['created_Time'][0:5])
print(df5['created_Date'][0:5])
# Out:
# 7     16:18:00
# 14    15:54:00
# 16    15:34:00
# 21    15:02:00
# 22    14:58:00
# Name: created_Time, dtype: object
# 7     2022-10-25
# 14    2022-10-25
# 16    2022-10-25
# 21    2022-10-25
# 22    2022-10-25
# Name: created_Date, dtype: object

# %%
df5['res_Time'] = df5['Resolved'].dt.time
df5['res_Date'] = df5['Resolved'].dt.date
print(df5['res_Time'][0:5])
print(df5['res_Date'][0:5])
# Out:
# 7     16:32:00
# 14    16:09:00
# 16    16:03:00
# 21    15:25:00
# 22    16:48:00
# Name: res_Time, dtype: object
# 7     2022-10-25
# 14    2022-10-25
# 16    2022-10-25
# 21    2022-10-25
# 22    2022-10-25
# Name: res_Date, dtype: object

# %%
from datetime import datetime ,timedelta

# %%
df5['duration'] = df5['Resolved'] - df5['Created']
#df5['dura_date'] = df5['res_Date'] - df5['created_Date']

# %%
df5.head(20)
# Out:
#                Created         Updated          Last Viewed  \
# 7  2022-10-25 16:18:00  10/25/22 16:32  2022-10-25 20:14:00
# 14 2022-10-25 15:54:00  10/25/22 16:09  2022-10-25 20:14:00
# 16 2022-10-25 15:34:00  10/25/22 16:03  2022-10-25 20:14:00
# 21 2022-10-25 15:02:00  10/25/22 16:23  2022-10-25 20:14:00
# 22 2022-10-25 14:58:00  10/25/22 16:48  2022-10-25 20:14:00
# 26 2022-10-25 13:58:00  10/25/22 14:12  2022-10-25 20:14:00
# 30 2022-10-25 13:14:00  10/25/22 13:55  2022-10-25 20:14:00
# 34 2022-10-25 12:18:00  10/25/22 12:43  2022-10-25 20:14:00
# 38 2022-10-25 11:54:00  10/25/22 13:00  2022-10-25 20:14:00
# 41 2022-10-25 11:42:00  10/25/22 13:06  2022-10-25 20:14:00
# 43 2022-10-25 11:34:00  10/25/22 13:17  2022-10-25 20:14:00
# 45 2022-10-25 11:26:00  10/25/22 13:06  2022-10-25 20:14:00
# 46 2022-10-25 11:18:00  10/25/22 12:39  2022-10-25 20:14:00
# 48 2022-10-25 11:02:00  10/25/22 11:52  2022-10-25 20:14:00
# 49 2022-10-25 10:58:00  10/25/22 12:30  2022-10-25 20:14:00
# ...

# %%
df5["dura_sec"] = df5["duration"].apply(lambda x: x.total_seconds())

# %%
df5["dura_hour"] = df5["duration"].apply(lambda x: x.total_seconds()/60)

# %%
df5.to_excel('durations.xlsx')

# %%
df5.head()
# Out:
#                Created         Updated          Last Viewed  \
# 7  2022-10-25 16:18:00  10/25/22 16:32  2022-10-25 20:14:00
# 14 2022-10-25 15:54:00  10/25/22 16:09  2022-10-25 20:14:00
# 16 2022-10-25 15:34:00  10/25/22 16:03  2022-10-25 20:14:00
# 21 2022-10-25 15:02:00  10/25/22 16:23  2022-10-25 20:14:00
# 22 2022-10-25 14:58:00  10/25/22 16:48  2022-10-25 20:14:00
#
#               Resolved created_Time created_Date  res_Time    res_Date  \
# 7  2022-10-25 16:32:00     16:18:00   2022-10-25  16:32:00  2022-10-25
# 14 2022-10-25 16:09:00     15:54:00   2022-10-25  16:09:00  2022-10-25
# 16 2022-10-25 16:03:00     15:34:00   2022-10-25  16:03:00  2022-10-25
# 21 2022-10-25 15:25:00     15:02:00   2022-10-25  15:25:00  2022-10-25
# 22 2022-10-25 16:48:00     14:58:00   2022-10-25  16:48:00  2022-10-25
#
#           duration  dura_sec  dura_hour
# 7  0 days 00:14:00     840.0       14.0
# 14 0 days 00:15:00     900.0       15.0
# 16 0 days 00:29:00    1740.0       29.0
# ...

# %%
df5['day_of_week'] = df5['Created'].dt.day_name()

# %%
ticket_frequency = df5['day_of_week'].value_counts()
print(ticket_frequency)
# Out:
# Tuesday      8773
# Wednesday    8375
# Monday       8341
# Thursday     8003
# Friday       5941
# Saturday     1160
# Sunday       1078
# Name: day_of_week, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x = 'day_of_week', data = df5, order = df5['day_of_week'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='count'>

# %%
df5['month'] = df5['Created'].dt.month_name()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.countplot(x = 'month', data = df5)
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
df5['duration'].describe()
# Out:
# count                         41671
# mean      3 days 03:05:46.642509179
# std      25 days 18:48:05.869179030
# min                 0 days 00:00:00
# 25%                 0 days 00:43:00
# 50%                 0 days 04:23:00
# 75%                 1 days 05:05:00
# max              1451 days 06:22:00
# Name: duration, dtype: object

# %%
df5.head()
# Out:
#                Created         Updated          Last Viewed  \
# 7  2022-10-25 16:18:00  10/25/22 16:32  2022-10-25 20:14:00
# 14 2022-10-25 15:54:00  10/25/22 16:09  2022-10-25 20:14:00
# 16 2022-10-25 15:34:00  10/25/22 16:03  2022-10-25 20:14:00
# 21 2022-10-25 15:02:00  10/25/22 16:23  2022-10-25 20:14:00
# 22 2022-10-25 14:58:00  10/25/22 16:48  2022-10-25 20:14:00
#
#               Resolved created_Time created_Date  res_Time    res_Date  \
# 7  2022-10-25 16:32:00     16:18:00   2022-10-25  16:32:00  2022-10-25
# 14 2022-10-25 16:09:00     15:54:00   2022-10-25  16:09:00  2022-10-25
# 16 2022-10-25 16:03:00     15:34:00   2022-10-25  16:03:00  2022-10-25
# 21 2022-10-25 15:25:00     15:02:00   2022-10-25  15:25:00  2022-10-25
# 22 2022-10-25 16:48:00     14:58:00   2022-10-25  16:48:00  2022-10-25
#
#           duration  dura_sec  dura_hour day_of_week    month
# 7  0 days 00:14:00     840.0       14.0     Tuesday  October
# ...

# %%
df5.describe()
# Out:
#                          duration      dura_sec     dura_hour
# count                       41671  4.167100e+04  4.167100e+04
# mean    3 days 03:05:46.642509179  2.703466e+05  4.505777e+03
# std    25 days 18:48:05.869179030  2.227686e+06  3.712810e+04
# min               0 days 00:00:00  0.000000e+00  0.000000e+00
# 25%               0 days 00:43:00  2.580000e+03  4.300000e+01
# 50%               0 days 04:23:00  1.578000e+04  2.630000e+02
# 75%               1 days 05:05:00  1.047000e+05  1.745000e+03
# max            1451 days 06:22:00  1.253893e+08  2.089822e+06

# %%
df5.to_excel('Viz_df.xlsx')
